# %%
import pandas as pd

# %%
generated_hn = pd.read_csv('hackernews_original_eval_df.csv')

# %%
generated_hn['evaluated_text'] = generated_hn['evaluated_text'].fillna('empty')

# %%
generated_hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               400 non-null    object
#  1   CommentTime        400 non-null    object
#  2   CommentAuthor      400 non-null    object
#  3   ParentTitle        400 non-null    object
#  4   clean_text         400 non-null    object
#  5   location           400 non-null    object
#  6   technologies       400 non-null    object
#  7   embedding          400 non-null    object
#  8   company            400 non-null    object
#  9   title              400 non-null    object
#  10  prompt             400 non-null    object
#  11  q_value            400 non-null    float64
#  12  generated_text     399 non-null    object
#  13  evaluated_text     400 non-null    object
#  14  sr_female          400 non-null    float64
#  15  sr_male            400 non-null    float64
# ...

# %%
generated_hn
# Out:
#                                                   text  \
# 0    Enchanted Labs - (San Francisco, CA) - Ex-Face...
# 1    Euclid Inc - San Francisco's Mission District,...
# 2    AppHero (apphero.com) - Toronto, Ontario, Cana...
# 3    Toronto - Uken Games\nSoftware Engineer (full ...
# 4    Toronto - Uken Games\nSoftware Engineer (full ...
# ..                                                 ...
# 395  New York, NY.\nFull Time.\n<a href="http://www...
# 396  Location: Palo Alto, CA in a house just a bloc...
# 397  Redwood City. Full-time. Course Hero. Sr. Soft...
# 398  Ersatz Labs - Pacifica, CA (peninsula, south o...
# 399  Roomorama - Rails Developers - both full-time ...
#
#                  CommentTime  CommentAuthor  \
# 0    2014-10-03 20:53:43 UTC       JuliaLam
# 1    2014-06-01 19:09:02 UTC   stevewilhelm
# 2    2012-04-01 16:09:32 UTC         jsatok
# 3    2013-10-01 17:42:10 UTC     lamplightr
# 4    2013-10-01 17:42:10 UTC     lamplightr
# ...

# %%
generated_hn.loc[1]['evaluated_text'],generated_hn.loc[0]['clean_text']
# Out:
# ('Euclid Inc - San Francisco\'s Mission District, Four full-time Positions,  (euclidanalytics.com)\nEuclid is Google Analytics for the physical world. Euclid is leveling the playing field for brick and mortar retailers and changing the the way top retailers use consumer behavioral data.\nAs a Data Engineer, you will help solve some of the most vexing questions we have today.\nAs a Full Stack Engineer at Euclid, you will be building Rails applications and APIs, from our cloud-based databases and back-end services to our dynamic JavaScript front-end.\nThe Front End engineer is a key technical lead in visualizing the insights we provide our retail customers.\nDetails can be found at: <a href="http://euclidanalytics.com/about/careers/" >',
# ...
